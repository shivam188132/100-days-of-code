# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/vehicle-co2-emissions-dataset/co2.csv

# %%
df = pd.read_csv('/kaggle/input/vehicle-co2-emissions-dataset/co2.csv')

# %%
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# 1              M6         Z                              11.2
# 2             AV7         Z                               6.0
# 3             AS6         Z                              12.7
# 4             AS6         Z                              12.1
# ...           ...       ...                               ...
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                              33                  196
# 1                              29                  221
# 2                              48                  136
# 3                              25                  255
# 4                              27                  244
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [7385 rows x 12 columns]

# %% [markdown]
# How big is the data ?

# %%
df.shape
# Out:
# (7385, 12)

# %% [markdown]
# How my dataset look like ?

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244

# %% [markdown]
# **Some Datasets are not similiar as they are in the begining how to check them all**

# %%
df.sample(5)
# Out:
#          Make                           Model Vehicle Class  Engine Size(L)  \
# 5913    HONDA                         Odyssey       MINIVAN             3.5
# 6000     JEEP  Cherokee 4X4 Active Drive Lock   SUV - SMALL             2.0
# 3185    SCION                              iM      MID-SIZE             1.8
# 2016  PORSCHE                     BOXSTER GTS    TWO-SEATER             3.4
# 818      MINI      JOHN COOPER WORKS ROADSTER    TWO-SEATER             1.6
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 5913          6          AS9         X                              12.6
# 6000          4           A9         X                              11.8
# 3185          4          AV7         X                               8.3
# 2016          6          AM7         Z                              10.9
# 818           4           A6         Z                               9.3
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 5913                              8.4                              10.7
# 6000                              9.2                              10.6
# 3185                              6.3                               7.4
# 2016                              7.7                               9.5
# 818                               7.0                               8.3
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 5913                           26                  252
# 6000                           27                  249
# 3185                           38                  173
# 2016                           30                  218
# 818                            34                  191

# %% [markdown]
# All informations about the column can be checked by

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %% [markdown]
# is there any missing value in the data ?

# %%
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %% [markdown]
# how does the data look like mathematically ?

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# min                           4.000000                          4.100000
# 25%                           7.500000                          8.900000
# 50%                           8.700000                         10.600000
# 75%                          10.200000                         12.600000
# max                          20.600000                         26.100000
#
#        Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# count                  7385.000000          7385.000000
# mean                     27.481652           250.584699
# std                       7.231879            58.512679
# min                      11.000000            96.000000
# 25%                      22.000000           208.000000
# 50%                      27.000000           246.000000
# 75%                      32.000000           288.000000
# max                      69.000000           522.000000

# %% [markdown]
# is there any duplicate value in our column ?

# %%
df.duplicated().sum()
# Out:
# 1103

# %%
duplicates = df[df.duplicated(keep=False)]
duplicates
# Out:
#               Make       Model            Vehicle Class  Engine Size(L)  \
# 4            ACURA     RDX AWD              SUV - SMALL             3.5
# 5            ACURA         RLX                 MID-SIZE             3.5
# 12      ALFA ROMEO          4C               TWO-SEATER             1.8
# 13    ASTON MARTIN         DB9              MINICOMPACT             5.9
# 15    ASTON MARTIN  V8 VANTAGE               TWO-SEATER             4.7
# ...            ...         ...                      ...             ...
# 7356        TOYOTA      Tundra  PICKUP TRUCK - STANDARD             5.7
# 7365    VOLKSWAGEN    Golf GTI                  COMPACT             2.0
# 7366    VOLKSWAGEN       Jetta                  COMPACT             1.4
# 7367    VOLKSWAGEN       Jetta                  COMPACT             1.4
# 7368    VOLKSWAGEN   Jetta GLI                  COMPACT             2.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 4             6          AS6         Z                              12.1
# 5             6          AS6         Z                              11.9
# 12            4          AM6         Z                               9.7
# 13           12           A6         Z                              18.0
# 15            8          AM7         Z                              17.4
# ...         ...          ...       ...                               ...
# 7356          8          AS6         X                              17.7
# 7365          4           M6         X                               9.8
# 7366          4          AS8         X                               7.8
# 7367          4           M6         X                               7.9
# 7368          4          AM7         X                               9.3
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 4                                 8.7                              10.6
# 5                                 7.7                              10.0
# 12                                6.9                               8.4
# 13                               12.6                              15.6
# 15                               11.3                              14.7
# ...                               ...                               ...
# 7356                             13.6                              15.9
# 7365                              7.3                               8.7
# 7366                              5.9                               7.0
# 7367                              5.9                               7.0
# 7368                              7.2                               8.4
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 4                              27                  244
# 5                              28                  230
# 12                             34                  193
# 13                             18                  359
# 15                             19                  338
# ...                           ...                  ...
# 7356                           18                  371
# 7365                           32                  203
# 7366                           40                  162
# 7367                           40                  163
# 7368                           34                  196
#
# [2102 rows x 12 columns]

# %%
duplicates_except_first = df[df.duplicated(keep='first')]
duplicates_except_first
# Out:
#               Make       Model            Vehicle Class  Engine Size(L)  \
# 1075         ACURA     RDX AWD              SUV - SMALL             3.5
# 1076         ACURA         RLX                 MID-SIZE             3.5
# 1081    ALFA ROMEO          4C               TWO-SEATER             1.8
# 1082  ASTON MARTIN         DB9              MINICOMPACT             5.9
# 1084  ASTON MARTIN  V8 VANTAGE               TWO-SEATER             4.7
# ...            ...         ...                      ...             ...
# 7356        TOYOTA      Tundra  PICKUP TRUCK - STANDARD             5.7
# 7365    VOLKSWAGEN    Golf GTI                  COMPACT             2.0
# 7366    VOLKSWAGEN       Jetta                  COMPACT             1.4
# 7367    VOLKSWAGEN       Jetta                  COMPACT             1.4
# 7368    VOLKSWAGEN   Jetta GLI                  COMPACT             2.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 1075          6          AS6         Z                              12.1
# 1076          6          AS6         Z                              11.9
# 1081          4          AM6         Z                               9.7
# 1082         12           A6         Z                              18.0
# 1084          8          AM7         Z                              17.4
# ...         ...          ...       ...                               ...
# 7356          8          AS6         X                              17.7
# 7365          4           M6         X                               9.8
# 7366          4          AS8         X                               7.8
# 7367          4           M6         X                               7.9
# 7368          4          AM7         X                               9.3
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1075                              8.7                              10.6
# 1076                              7.7                              10.0
# 1081                              6.9                               8.4
# 1082                             12.6                              15.6
# 1084                             11.3                              14.7
# ...                               ...                               ...
# 7356                             13.6                              15.9
# 7365                              7.3                               8.7
# 7366                              5.9                               7.0
# 7367                              5.9                               7.0
# 7368                              7.2                               8.4
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 1075                           27                  244
# 1076                           28                  230
# 1081                           34                  193
# 1082                           18                  359
# 1084                           19                  338
# ...                           ...                  ...
# 7356                           18                  371
# 7365                           32                  203
# 7366                           40                  162
# 7367                           40                  163
# 7368                           34                  196
#
# [1103 rows x 12 columns]

# %%
# Example of specifying columns to check for duplicates
manual_duplicates_check = df[df.duplicated(subset=['Make', 'Model','Vehicle Class', 'Engine Size(L)', 'Cylinders'], keep='first')]
manual_duplicates_check
# Out:
#               Make         Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 8            ACURA        TL AWD        MID-SIZE             3.7          6
# 10           ACURA           TSX         COMPACT             2.4          4
# 16    ASTON MARTIN    V8 VANTAGE      TWO-SEATER             4.7          8
# 18    ASTON MARTIN  V8 VANTAGE S      TWO-SEATER             4.7          8
# 22            AUDI    A4 QUATTRO         COMPACT             2.0          4
# ...            ...           ...             ...             ...        ...
# 7380         VOLVO   XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381         VOLVO   XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382         VOLVO   XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383         VOLVO   XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384         VOLVO   XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 8              M6         Z                              13.4
# 10             M6         Z                              11.2
# 16             M6         Z                              18.1
# 18             M6         Z                              18.1
# 22             M6         Z                              10.8
# ...           ...       ...                               ...
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 8                                 9.5                              11.6
# 10                                8.1                               9.8
# 16                               12.2                              15.4
# 18                               12.2                              15.4
# 22                                7.5                               9.3
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 8                              24                  267
# 10                             29                  225
# 16                             18                  354
# 18                             18                  354
# 22                             30                  214
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [4790 rows x 12 columns]

# %% [markdown]
# Yes, you are correct in your understanding. When you use the duplicated() method with the subset parameter specifying certain columns, it checks for duplicates based on whether rows have identical values in all the columns you listed in the subset. If two or more rows have the same values in these columns, then, based on your keep='first' setting, the first occurrence of such a row is considered unique, and subsequent rows with the same values in the specified columns are flagged as duplicates.

# %%
duplicates_except_first[(duplicates_except_first['Make'] == 'ACURA') & (duplicates_except_first['Model'] == 'ILX')]
# Out:
#        Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 4371  ACURA   ILX       COMPACT             2.4          4          AM8
# 6503  ACURA   ILX       COMPACT             2.4          4          AM8
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 4371         Z                               9.4
# 6503         Z                               9.9
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 4371                              6.8                               8.2
# 6503                              7.0                               8.6
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 4371                           34                  192
# 6503                           33                  199

# %%
duplicates_except_first.sample(5)
# Out:
#                Make                        Model Vehicle Class  \
# 7182  MERCEDES-BENZ                     AMG S 65     FULL-SIZE
# 7103          LEXUS                   RC 300 AWD    SUBCOMPACT
# 4959           JEEP  CHEROKEE 4X4 ACTIVE DRIVE I   SUV - SMALL
# 4440            BMW                   230i COUPE    SUBCOMPACT
# 7264        PORSCHE        Panamera 4S Executive     FULL-SIZE
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 7182             6.0         12           A7         Z
# 7103             3.5          6          AS6         Z
# 4959             2.4          4           A9         X
# 4440             2.0          4          AS8         Z
# 7264             2.9          6          AM8         Z
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 7182                              18.6                             10.9
# 7103                              13.1                              9.8
# 4959                              11.3                              8.4
# 4440                               9.8                              6.8
# 7264                              13.1                              8.9
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 7182                              15.1                           19
# 7103                              11.2                           25
# 4959                              10.0                           28
# 4440                               8.4                           34
# 7264                              11.2                           25
#
#       CO2 Emissions(g/km)
# 7182                  356
# 7103                  262
# 4959                  235
# 4440                  197
# 7264                  261

# %%
duplicates_except_first[(duplicates_except_first['Make'] == 'INFINITI') & (duplicates_except_first['Model'] == 'QX60 AWD')]
# Out:
#           Make     Model Vehicle Class  Engine Size(L)  Cylinders  \
# 5963  INFINITI  QX60 AWD   SUV - SMALL             3.5          6
# 6976  INFINITI  QX60 AWD   SUV - SMALL             3.5          6
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 5963          AV7         Z                              12.5
# 6976          AV7         Z                              12.5
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 5963                              9.0                              10.9
# 6976                              9.0                              10.9
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 5963                           26                  257
# 6976                           26                  257

# %%
duplicates_except_first[(duplicates_except_first['Make'] == 'MERCEDES-BENZ') & (duplicates_except_first['Vehicle Class'] == 'SUBCOMPACT')]
# Out:
#                Make                       Model Vehicle Class  Engine Size(L)  \
# 1833  MERCEDES-BENZ          C 350 4MATIC COUPE    SUBCOMPACT             3.5
# 1834  MERCEDES-BENZ                 C 350 COUPE    SUBCOMPACT             3.5
# 4077  MERCEDES-BENZ             E 400 CABRIOLET    SUBCOMPACT             3.0
# 4079  MERCEDES-BENZ             E 550 CABRIOLET    SUBCOMPACT             4.7
# 4080  MERCEDES-BENZ                 E 550 COUPE    SUBCOMPACT             4.7
# 7162  MERCEDES-BENZ   AMG C 43 4MATIC Cabriolet    SUBCOMPACT             3.0
# 7163  MERCEDES-BENZ       AMG C 43 4MATIC Coupe    SUBCOMPACT             3.0
# 7167  MERCEDES-BENZ        AMG C 63 S Cabriolet    SUBCOMPACT             4.0
# 7168  MERCEDES-BENZ            AMG C 63 S Coupe    SUBCOMPACT             4.0
# 7171  MERCEDES-BENZ  AMG E 53 4MATIC+ Cabriolet    SUBCOMPACT             3.0
# 7172  MERCEDES-BENZ      AMG E 53 4MATIC+ Coupe    SUBCOMPACT             3.0
# 7180  MERCEDES-BENZ  AMG S 63 4MATIC+ Cabriolet    SUBCOMPACT             4.0
# 7184  MERCEDES-BENZ      C 300 4MATIC Cabriolet    SUBCOMPACT             2.0
# 7185  MERCEDES-BENZ          C 300 4MATIC Coupe    SUBCOMPACT             2.0
# 7188  MERCEDES-BENZ      E 450 4MATIC Cabriolet    SUBCOMPACT             3.0
# 7189  MERCEDES-BENZ          E 450 4MATIC Coupe    SUBCOMPACT             3.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 1833          6          AS7         Z                              12.1
# 1834          6          AS7         Z                              12.1
# 4077          6          AS7         Z                              11.5
# 4079          8          AS7         Z                              13.7
# 4080          8          AS7         Z                              13.4
# 7162          6           A9         Z                              12.7
# 7163          6           A9         Z                              12.9
# 7167          8           A9         Z                              13.9
# 7168          8           A9         Z                              13.9
# 7171          6           A9         Z                              12.5
# 7172          6           A9         Z                              12.3
# 7180          8           A9         Z                              15.8
# 7184          4           A9         Z                              11.3
# 7185          4           A9         Z                              10.9
# 7188          6           A9         Z                              12.7
# 7189          6           A9         Z                              12.5
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1833                              8.7                              10.6
# 1834                              8.6                              10.5
# 4077                              8.1                              10.0
# 4079                              9.2                              11.7
# 4080                              8.9                              11.4
# 7162                              9.2                              11.2
# 7163                              8.8                              11.1
# 7167                              9.7                              12.0
# 7168                              9.2                              11.8
# 7171                              9.0                              10.9
# 7172                              8.5                              10.6
# 7180                              9.8                              13.1
# 7184                              8.1                               9.9
# 7185                              7.7                               9.5
# 7188                             10.1                              11.6
# 7189                              9.1                              11.0
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 1833                           27                  244
# 1834                           27                  242
# 4077                           28                  233
# 4079                           24                  275
# 4080                           25                  268
# 7162                           25                  263
# 7163                           25                  255
# 7167                           24                  282
# 7168                           24                  277
# 7171                           26                  245
# 7172                           27                  237
# 7180                           22                  306
# 7184                           29                  231
# 7185                           30                  221
# 7188                           24                  271
# 7189                           26                  257

# %%
cleaned_df = df.drop_duplicates(subset=['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders'], keep='first')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2595 entries, 0 to 7379
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              2595 non-null   object
#  1   Model                             2595 non-null   object
#  2   Vehicle Class                     2595 non-null   object
#  3   Engine Size(L)                    2595 non-null   float64
#  4   Cylinders                         2595 non-null   int64
#  5   Transmission                      2595 non-null   object
#  6   Fuel Type                         2595 non-null   object
#  7   Fuel Consumption City (L/100 km)  2595 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   2595 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  2595 non-null   float64
#  10  Fuel Consumption Comb (mpg)       2595 non-null   int64
#  11  CO2 Emissions(g/km)               2595 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 263.6+ KB

# %%
cleaned_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Now our data is perfectly cleaned and is ready for further operations**

# %% [markdown]
# **Exploratory data analysis(EDA)**
# * univariate analysis (single column analysis)
# * Bivarite analysis ( treating 2 columns together analysis)
# * Multivariate anlaysis ( multiple column analysis)

# %% [markdown]
# [![image.png](attachment:3a0c4b49-b129-4c9c-ada1-3770c2e535a4.png)](http://)

# %%
cleaned_df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244

# %%
cleaned_df.shape
# Out:
# (2595, 12)

# %% [markdown]
# **Univariate Analysis**

# %% [markdown]
# 1. *Categorical Data*

# %%
cleaned_df['Make'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Make'>

# %%
import seaborn as sns

# %%
cleaned_df['Model'].value_counts()
# Out:
# Model
# F-150                             6
# F-150 4X4                         6
# Sierra 4WD                        5
# TERRAIN AWD                       5
# CAMARO                            5
#                                  ..
# NX 300h AWD                       1
# NX 200t AWD F SPORT               1
# NX 200t AWD                       1
# RANGE ROVER SPORT SUPERCHARGED    1
# XC40 T4 AWD                       1
# Name: count, Length: 2053, dtype: int64

# %% [markdown]
# **if we are doing univariate analysis and we have a categorical data either we can do a countplot or we can do a pie chart plot**

# %%
cleaned_df['Model'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# The plot you shared is overcrowded because there are too many unique values in the Model column to effectively visualize as a pie chart. Here's how you can improve the visualization:
#
# Options to Address the Issue:
# Aggregate Data:
#
# Group similar models or categories into broader categories.
# For example, combine similar types of models into categories like SUV, Sedan, Truck, etc.
# Limit the Number of Categories:
#
# Visualize only the top 10 or 15 most common models and group the rest as "Other".

# %%
cleaned_df['Model'].value_counts().nlargest(10).plot(kind='pie', autopct='%1.2f%%', title='Top 10 Models')
# Out:
# <Axes: title={'center': 'Top 10 Models'}, ylabel='count'>
